# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv( 'data/dataset.csv')

# %%
plt.scatter(df['T2'],df['T4'], s=0.5)
plt.xlabel('T2')
plt.ylabel('T4')
plt.title('Scatterplot of T2 and T4')
plt.show()
